# %%
import pandas as pd
from fuzzywuzzy import fuzz

# %%
df_birth_and_emerg = pd.read_csv("../../data/df_birth_and_emerg.csv")

# %%
reference_df = pd.read_csv("../../data/reference_df.csv")

# %%
df_birth_and_emerg
# Out:
#        Unnamed: 0  uniqueID                            drugName  \
# 0               2     92703                              Lybrel
# 1               3    138000                          Ortho Evra
# 2               6    165907                      Levonorgestrel
# 3               9     48928  Ethinyl estradiol / levonorgestrel
# 4              14     98494                           Nexplanon
# ...           ...       ...                                 ...
# 31246      161268     76151                              Portia
# 31247      161269     73058   Ethinyl estradiol / norethindrone
# 31248      161271    148859                              Mirena
# 31249      161273    109111                           Nexplanon
# 31250      161291    164345                      Junel 1.5 / 30
#
#                      condition  \
# 0                Birth Control
# 1                Birth Control
# 2      Emergency Contraception
# 3                Birth Control
# 4                Birth Control
# ...                        ...
# 31246            Birth Control
# 31247            Birth Control
# 31248            Birth Control
# 31249            Birth Control
# 31250            Birth Control
#
#                                                   review  rating       date  \
# 0      "I used to take another oral contraceptive, wh...       5  14-Dec-09
# 1      "This is my first time using any form of birth...       8   3-Nov-15
# 2      "He pulled out, but he cummed a bit in me. I t...       1   7-Mar-17
# 3      "I had been on the pill for many years. When m...       8   8-Dec-16
# 4      "Started Nexplanon 2 months ago because I have...       3   7-Aug-14
# ...                                                  ...     ...        ...
# 31246  "I switched to Portia 12 days ago when I start...       1  28-Jan-14
# 31247  "When I first starting taking Lo Loestrin Fe, ...      10  20-Apr-15
# 31248  "My experience: Painful insertion but I expect...      10  26-Jan-16
# 31249  "I have had the Nexplanon since Dec. 27, 2016 ...       6   6-Apr-17
# 31250  "This would be my second month on Junel. I&#03...       6  27-May-15
#
#        usefulCount
# 0               17
# 1               10
# 2                5
# 3                1
# 4               10
# ...            ...
# 31246            9
# 31247           13
# 31248            4
# 31249            0
# 31250            0
#
# [31251 rows x 8 columns]

# %%
reference_df
# Out:
#      Unnamed: 0              brand name                     generic name  \
# 0             0        Nexplanon (Pro)                      etonogestrel
# 1             1  Plan B One-Step (Pro)                    levonorgestrel
# 2             2           Mirena (Pro)                    levonorgestrel
# 3             3     Depo Provera (Pro)               medroxyprogesterone
# 4             4          Kyleena (Pro)                    levonorgestrel
# ..          ...                     ...                              ...
# 268         268                  condom  Latex Polyurethane Polyisoprene
# 269         269   Depo-SubQ Provera 104                              NaN
# 270         270                  FemCap              spermicide Silicone
# 271         271            Today sponge                       spermidice
# 272         272              Spermicide                       spermicide
#
#                type
# 0          standard
# 1          standard
# 2          standard
# 3          standard
# 4          standard
# ..              ...
# 268     Male condom
# 269  Shot/injection
# 270    Cervical cap
# 271          Sponge
# 272             NaN
#
# [273 rows x 4 columns]

# %%
reference_df = reference_df.drop(columns=["Unnamed: 0"])

# %%
reference_df
# Out:
#                  brand name                     generic name            type
# 0          Nexplanon (Pro)                      etonogestrel        standard
# 1    Plan B One-Step (Pro)                    levonorgestrel        standard
# 2             Mirena (Pro)                    levonorgestrel        standard
# 3       Depo Provera (Pro)               medroxyprogesterone        standard
# 4            Kyleena (Pro)                    levonorgestrel        standard
# ..                      ...                              ...             ...
# 268                  condom  Latex Polyurethane Polyisoprene     Male condom
# 269   Depo-SubQ Provera 104                              NaN  Shot/injection
# 270                  FemCap              spermicide Silicone    Cervical cap
# 271            Today sponge                       spermidice          Sponge
# 272              Spermicide                       spermicide             NaN
#
# [273 rows x 3 columns]

# %%
#function comparing drugName with both brand name and generic name

def find_match(drug_name, ref_df):
    
    for idx, row in ref_df.iterrows():
        brand_similarity = fuzz.ratio(drug_name, row['brand name'])
        generic_similarity = fuzz.ratio(drug_name, row['generic name'])
        
        if 70 <= brand_similarity <= 100 or 70 <= generic_similarity <= 100:
            return pd.Series([row['generic name'], row['type']])
    return pd.Series([None, None])

# Step 3: Apply the function to each row in test_df to find matching rows in reference_df
df_birth_and_emerg[['matched_generic_name', 'matched_type']] = df_birth_and_emerg['drugName'].apply(find_match, ref_df=reference_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 14
#      11     return pd.Series([None, None])
#      13 # Step 3: Apply the function to each row in test_df to find matching rows in reference_df
# ---> 14 df_birth_and_emerg[['matched_generic_name', 'matched_type']] = df_birth_and_emerg['drugName'].apply(find_match, ref_df=reference_df)
#
# File /opt/anaconda3/envs/test3/lib/python3.11/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File /opt/anaconda3/envs/test3/lib/python3.11/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File /opt/anaconda3/envs/test3/lib/python3.11/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /opt/anaconda3/envs/test3/lib/python3.11/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File /opt/anaconda3/envs/test3/lib/python3.11/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# File /opt/anaconda3/envs/test3/lib/python3.11/site-packages/pandas/core/apply.py:1496, in SeriesApply.apply_standard.<locals>.curried(x)
#    1495 def curried(x):
# -> 1496     return func(x, *self.args, **self.kwargs)
#
# Cell In[26], line 7, in find_match(drug_name, ref_df)
#       5 for idx, row in ref_df.iterrows():
#       6     brand_similarity = fuzz.ratio(drug_name, row['brand name'])
# ----> 7     generic_similarity = fuzz.ratio(drug_name, row['generic name'])
#       9     if 70 <= brand_similarity <= 100 or 70 <= generic_similarity <= 100:
#      10         return pd.Series([row['generic name'], row['type']])
#
# File /opt/anaconda3/envs/test3/lib/python3.11/site-packages/fuzzywuzzy/utils.py:38, in check_for_none.<locals>.decorator(*args, **kwargs)
#      36 if args[0] is None or args[1] is None:
#      37     return 0
# ---> 38 return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/test3/lib/python3.11/site-packages/fuzzywuzzy/utils.py:29, in check_for_equivalence.<locals>.decorator(*args, **kwargs)
#      27 if args[0] == args[1]:
#      28     return 100
# ---> 29 return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/test3/lib/python3.11/site-packages/fuzzywuzzy/utils.py:45, in check_empty_string.<locals>.decorator(*args, **kwargs)
#      43 @functools.wraps(func)
#      44 def decorator(*args, **kwargs):
# ---> 45     if len(args[0]) == 0 or len(args[1]) == 0:
#      46         return 0
#      47     return func(*args, **kwargs)
#
# TypeError: object of type 'float' has no len()

# %%
#Creating a function to compare drugName with both brand name and generic name

def find_match(drug_name, ref_df):
    
    #Checking if drug_name is not null
    
    if pd.isna(drug_name):
        return pd.Series([None, None])

    for idx, row in ref_df.iterrows():
        
        #Ensuring that both brand name and generic name are not null
        
        brand_name = row['brand name'] if pd.notna(row['brand name']) else ''
        generic_name = row['generic name'] if pd.notna(row['generic name']) else ''
        
        # Comparing drugName with brand name and generic name with fuzzy
        
        brand_similarity = fuzz.ratio(drug_name, brand_name)
        generic_similarity = fuzz.ratio(drug_name, generic_name)
        
        # If the similarity is within the 70-100% range, return the generic name and type
        
        if 70 <= brand_similarity <= 100 or 70 <= generic_similarity <= 100:
            return pd.Series([row['generic name'], row['type']])
    
    return pd.Series([None, None])

# Step 3: Apply the function to each row in test_df to find matching rows in reference_df
df_birth_and_emerg[['matched_generic_name', 'matched_type']] = df_birth_and_emerg['drugName'].apply(find_match, ref_df=reference_df)

# %%
df_birth_and_emerg
# Out:
#        Unnamed: 0  uniqueID                            drugName  \
# 0               2     92703                              Lybrel
# 1               3    138000                          Ortho Evra
# 2               6    165907                      Levonorgestrel
# 3               9     48928  Ethinyl estradiol / levonorgestrel
# 4              14     98494                           Nexplanon
# ...           ...       ...                                 ...
# 31246      161268     76151                              Portia
# 31247      161269     73058   Ethinyl estradiol / norethindrone
# 31248      161271    148859                              Mirena
# 31249      161273    109111                           Nexplanon
# 31250      161291    164345                      Junel 1.5 / 30
#
#                      condition  \
# 0                Birth Control
# 1                Birth Control
# 2      Emergency Contraception
# 3                Birth Control
# 4                Birth Control
# ...                        ...
# 31246            Birth Control
# 31247            Birth Control
# 31248            Birth Control
# 31249            Birth Control
# 31250            Birth Control
#
#                                                   review  rating       date  \
# 0      "I used to take another oral contraceptive, wh...       5  14-Dec-09
# 1      "This is my first time using any form of birth...       8   3-Nov-15
# 2      "He pulled out, but he cummed a bit in me. I t...       1   7-Mar-17
# 3      "I had been on the pill for many years. When m...       8   8-Dec-16
# 4      "Started Nexplanon 2 months ago because I have...       3   7-Aug-14
# ...                                                  ...     ...        ...
# 31246  "I switched to Portia 12 days ago when I start...       1  28-Jan-14
# 31247  "When I first starting taking Lo Loestrin Fe, ...      10  20-Apr-15
# 31248  "My experience: Painful insertion but I expect...      10  26-Jan-16
# 31249  "I have had the Nexplanon since Dec. 27, 2016 ...       6   6-Apr-17
# 31250  "This would be my second month on Junel. I&#03...       6  27-May-15
#
#        usefulCount               matched_generic_name  \
# 0               17                               None
# 1               10                               None
# 2                5                       etonogestrel
# 3                1  ethinyl estradiol / norethindrone
# 4               10                       etonogestrel
# ...            ...                                ...
# 31246            9                               None
# 31247           13  ethinyl estradiol / norethindrone
# 31248            4                     levonorgestrel
# 31249            0                       etonogestrel
# 31250            0  ethinyl estradiol / norethindrone
#
#                      matched_type
# 0                            None
# 1                            None
# 2                        standard
# 3                        standard
# 4                        standard
# ...                           ...
# 31246                        None
# 31247                    standard
# 31248  Intrauterine devices (IUD)
# 31249                    standard
# 31250                    standard
#
# [31251 rows x 10 columns]

# %%
df_birth_and_emerg["condition"].value_counts()
# Out:
# condition
# Birth Control              28788
# Emergency Contraception     2463
# Name: count, dtype: int64

# %%
df_birth_and_emerg.to_csv("../../data/birth_and_emerg_MATCHED.csv")

# %%
df_birth_and_emerg.isnull().sum()
# Out:
# Unnamed: 0                 0
# uniqueID                   0
# drugName                   0
# condition                  0
# review                     0
# rating                     0
# date                       0
# usefulCount                0
# matched_generic_name    3888
# matched_type            3888
# dtype: int64

# %%
df_birth_and_emerg
# Out:
#        Unnamed: 0  uniqueID                            drugName  \
# 0               2     92703                              Lybrel
# 1               3    138000                          Ortho Evra
# 2               6    165907                      Levonorgestrel
# 3               9     48928  Ethinyl estradiol / levonorgestrel
# 4              14     98494                           Nexplanon
# ...           ...       ...                                 ...
# 31246      161268     76151                              Portia
# 31247      161269     73058   Ethinyl estradiol / norethindrone
# 31248      161271    148859                              Mirena
# 31249      161273    109111                           Nexplanon
# 31250      161291    164345                      Junel 1.5 / 30
#
#                      condition  \
# 0                Birth Control
# 1                Birth Control
# 2      Emergency Contraception
# 3                Birth Control
# 4                Birth Control
# ...                        ...
# 31246            Birth Control
# 31247            Birth Control
# 31248            Birth Control
# 31249            Birth Control
# 31250            Birth Control
#
#                                                   review  rating       date  \
# 0      "I used to take another oral contraceptive, wh...       5  14-Dec-09
# 1      "This is my first time using any form of birth...       8   3-Nov-15
# 2      "He pulled out, but he cummed a bit in me. I t...       1   7-Mar-17
# 3      "I had been on the pill for many years. When m...       8   8-Dec-16
# 4      "Started Nexplanon 2 months ago because I have...       3   7-Aug-14
# ...                                                  ...     ...        ...
# 31246  "I switched to Portia 12 days ago when I start...       1  28-Jan-14
# 31247  "When I first starting taking Lo Loestrin Fe, ...      10  20-Apr-15
# 31248  "My experience: Painful insertion but I expect...      10  26-Jan-16
# 31249  "I have had the Nexplanon since Dec. 27, 2016 ...       6   6-Apr-17
# 31250  "This would be my second month on Junel. I&#03...       6  27-May-15
#
#        usefulCount               matched_generic_name  \
# 0               17                               None
# 1               10                               None
# 2                5                       etonogestrel
# 3                1  ethinyl estradiol / norethindrone
# 4               10                       etonogestrel
# ...            ...                                ...
# 31246            9                               None
# 31247           13  ethinyl estradiol / norethindrone
# 31248            4                     levonorgestrel
# 31249            0                       etonogestrel
# 31250            0  ethinyl estradiol / norethindrone
#
#                      matched_type
# 0                            None
# 1                            None
# 2                        standard
# 3                        standard
# 4                        standard
# ...                           ...
# 31246                        None
# 31247                    standard
# 31248  Intrauterine devices (IUD)
# 31249                    standard
# 31250                    standard
#
# [31251 rows x 10 columns]

# %%
df_birth_and_emerg[df_birth_and_emerg["matched_type"] == "emergency"]
# Out:
#        Unnamed: 0  uniqueID     drugName                condition  \
# 40            197     26839   Ulipristal  Emergency Contraception
# 75            383      6471       Ocella            Birth Control
# 107           529      6482       Ocella            Birth Control
# 145           731    213061   EContra EZ  Emergency Contraception
# 298          1554      6425       Ocella            Birth Control
# ...           ...       ...          ...                      ...
# 30893      159443    105074  Next Choice  Emergency Contraception
# 30934      159640      6427       Ocella            Birth Control
# 30971      159868      6389       Ocella            Birth Control
# 31096      160618     26821   Ulipristal  Emergency Contraception
# 31116      160725      6467       Ocella            Birth Control
#
#                                                   review  rating       date  \
# 40     "This pill works!\r\r\nI decided to share my e...      10   8-Sep-16
# 75     "I&#039;m 20, 5ft and 97lbs. I&#039;ve been on...       8   2-Feb-13
# 107    "I&#039;ve been taking Ocella for 4 months, an...       9  19-Oct-09
# 145    "I had unprotected sex the day before I starte...      10   2-Aug-16
# 298    "I have been on Ocella now for over 2 years.  ...       9   2-Jun-11
# ...                                                  ...     ...        ...
# 30893  "I took next choice within 24 hours of unprote...       5  18-May-15
# 30934  "I have been taking Ocella now for about 6 mon...       5  20-Apr-11
# 30971  "Starting in elementary school, my acne was ho...       9  14-Jan-16
# 31096  "Ella gets it done. The side effects are minim...      10  25-Sep-13
# 31116  "No significant weight gain, No cramping durin...       9  13-Sep-13
#
#        usefulCount matched_generic_name matched_type
# 40              10           ulipristal    emergency
# 75              22           ulipristal    emergency
# 107              3           ulipristal    emergency
# 145             14       levonorgestrel    emergency
# 298              1           ulipristal    emergency
# ...            ...                  ...          ...
# 30893            9       levonorgestrel    emergency
# 30934            2           ulipristal    emergency
# 30971            4           ulipristal    emergency
# 31096           18           ulipristal    emergency
# 31116           11           ulipristal    emergency
#
# [171 rows x 10 columns]
